# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv('players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color='purple')
plt.show()

# %%
player_salary = fifa [['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color=['blue','green','black','yellow','orange'])
plt.show()

# %%
Portugal=fifa[fifa['nationality']=='Portugal']
Portugal.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 1        20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 41      218667  https://sofifa.com/player/218667/bernardo-mota...
# 85      212198  https://sofifa.com/player/212198/bruno-miguel-...
# 86      199482  https://sofifa.com/player/199482/anthony-lopes...
# 112     210514  https://sofifa.com/player/210514/joao-pedro-ca...
# 128     120533  https://sofifa.com/player/120533/kepler-lavera...
# 129     162347  https://sofifa.com/player/162347/joao-filipe-m...
# 151     197965  https://sofifa.com/player/197965/luis-miguel-a...
# 168     224411  https://sofifa.com/player/224411/goncalo-manue...
# 189     207566  https://sofifa.com/player/207566/william-silva...
#
#             short_name                                long_name  age  \
# 1    Cristiano Ronaldo      Cristiano Ronaldo dos Santos Aveiro   34
# 41      Bernardo Silva  Bernardo Mota Veiga de Carvalho e Silva   24
# 85     Bruno Fernandes            Bruno Miguel Borges Fernandes   24
# 86            A. Lopes                            Anthony Lopes   28
# 112       João Cancelo                João Pedro Cavaco Cancelo   25
# 128               Pepe             Képler Laveran Lima Ferreira   36
# 129      João Moutinho         João Filipe Iria Santos Moutinho   32
# 151              Pizzi             Luís Miguel Afonso Fernandes   29
# 168     Gonçalo Guedes          Gonçalo Manuel Ganchinho Guedes   22
# 189   William Carvalho                William Silva de Carvalho   27
#
#             dob  height_cm  weight_kg nationality                     club  \
# 1    1985-02-05        187         83    Portugal                 Juventus
# 41   1994-08-10        173         64    Portugal          Manchester City
# 85   1994-09-08        179         69    Portugal              Sporting CP
# 86   1990-10-01        184         81    Portugal       Olympique Lyonnais
# 112  1994-05-27        182         74    Portugal          Manchester City
# 128  1983-02-26        188         81    Portugal                 FC Porto
# 129  1986-09-08        170         61    Portugal  Wolverhampton Wanderers
# 151  1989-10-06        177         72    Portugal               SL Benfica
# 168  1996-11-29        179         68    Portugal              Valencia CF
# 189  1992-04-07        187         83    Portugal               Real Betis
#
#      ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 1    ...  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 41   ...  72+2  69+2  69+2  69+2  72+2  67+2  57+2  57+2  57+2  67+2
# 85   ...  77+2  77+2  77+2  77+2  77+2  74+2  68+2  68+2  68+2  74+2
# 86   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 112  ...  83+2  79+2  79+2  79+2  83+2  82+2  76+2  76+2  76+2  82+2
# 128  ...  73+3  76+3  76+3  76+3  73+3  75+3  82+3  82+3  82+3  75+3
# 129  ...  74+3  77+3  77+3  77+3  74+3  72+3  70+3  70+3  70+3  72+3
# 151  ...  75+3  75+3  75+3  75+3  75+3  71+3  65+3  65+3  65+3  71+3
# 168  ...  63+2  60+2  60+2  60+2  63+2  59+2  51+2  51+2  51+2  59+2
# 189  ...  73+3  80+3  80+3  80+3  73+3  73+3  78+3  78+3  78+3  73+3
#
# [10 rows x 104 columns]

# %%
Portugal.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 7790      251616  https://sofifa.com/player/251616/david-mota-te...
# 6754      240847  https://sofifa.com/player/240847/leonardo-mira...
# 9309      213646  https://sofifa.com/player/213646/miguel-aires-...
# 7006      198511  https://sofifa.com/player/198511/michael-simoe...
# 11173     252200  https://sofifa.com/player/252200/diogo-fesnard...
#
#             short_name                       long_name  age         dob  \
# 7790       David Carmo       David Mota Teixeira Carmo   19  1999-07-19
# 6754    Leonardo Rocha          Leonardo Miramar Rocha   21  1997-08-23
# 9309   Miguel Oliveira  Miguel Aires Fernandes Olivera   25  1994-05-25
# 7006              Mika        Michael Simões Domingues   28  1991-03-08
# 11173      Diogo Sousa    Diogo Fesnard Nogueira Sousa   20  1998-09-16
#
#        height_cm  weight_kg nationality               club  ...   lwb   ldm  \
# 7790         196         82    Portugal           SC Braga  ...  50+2  57+2
# 6754         196         80    Portugal          KAS Eupen  ...  42+2  37+2
# 9309         196         98    Portugal  Vitória Guimarães  ...   NaN   NaN
# 7006         195         90    Portugal      Os Belenenses  ...   NaN   NaN
# 11173        195         87    Portugal        Sporting CP  ...   NaN   NaN
#
#         cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 7790   57+2  57+2  50+2  53+2  65+2  65+2  65+2  53+2
# 6754   37+2  37+2  42+2  40+2  36+2  36+2  36+2  40+2
# 9309    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7006    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11173   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
Portugal.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 1        20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 41      218667  https://sofifa.com/player/218667/bernardo-mota...
# 112     210514  https://sofifa.com/player/210514/joao-pedro-ca...
# 249     227928  https://sofifa.com/player/227928/nelson-cabral...
# 129     162347  https://sofifa.com/player/162347/joao-filipe-m...
#
#             short_name                                long_name  age  \
# 1    Cristiano Ronaldo      Cristiano Ronaldo dos Santos Aveiro   34
# 41      Bernardo Silva  Bernardo Mota Veiga de Carvalho e Silva   24
# 112       João Cancelo                João Pedro Cavaco Cancelo   25
# 249      Nélson Semedo                     Nélson Cabral Semedo   25
# 129      João Moutinho         João Filipe Iria Santos Moutinho   32
#
#             dob  height_cm  weight_kg nationality                     club  \
# 1    1985-02-05        187         83    Portugal                 Juventus
# 41   1994-08-10        173         64    Portugal          Manchester City
# 112  1994-05-27        182         74    Portugal          Manchester City
# 249  1993-11-16        177         67    Portugal             FC Barcelona
# 129  1986-09-08        170         61    Portugal  Wolverhampton Wanderers
#
#      ...   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 1    ...  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 41   ...  72+2  69+2  69+2  69+2  72+2  67+2  57+2  57+2  57+2  67+2
# 112  ...  83+2  79+2  79+2  79+2  83+2  82+2  76+2  76+2  76+2  82+2
# 249  ...  81+2  77+2  77+2  77+2  81+2  80+2  76+2  76+2  76+2  80+2
# 129  ...  74+3  77+3  77+3  77+3  74+3  72+3  70+3  70+3  70+3  72+3
#
# [5 rows x 104 columns]

# %%
player_defending=fifa[['short_name','defending','nationality','club']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
real_madrid=fifa[fifa['club']=='Real Madrid']

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 76      201535  https://sofifa.com/player/201535/raphael-varan...
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...
#
#        short_name                          long_name  age         dob  \
# 18   Sergio Ramos                Sergio Ramos García   33  1986-03-30
# 42       Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 76      R. Varane                     Raphaël Varane   26  1993-04-25
# 94       Carvajal              Daniel Carvajal Ramos   27  1992-01-11
# 332  Éder Militão               Éder Gabriel Militão   21  1998-01-18
#
#      height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 18         184         82       Spain  Real Madrid  ...  80+3  84+3  84+3
# 42         185         84      Brazil  Real Madrid  ...  78+3  84+3  84+3
# 76         191         81      France  Real Madrid  ...  74+3  79+3  79+3
# 94         173         73       Spain  Real Madrid  ...  83+3  82+3  82+3
# 332        186         78      Brazil  Real Madrid  ...  78+2  76+2  76+2
#
#       rdm   rwb    lb   lcb    cb   rcb    rb
# 18   84+3  80+3  82+3  87+3  87+3  87+3  82+3
# 42   84+3  78+3  79+3  84+3  84+3  84+3  79+3
# 76   79+3  74+3  77+3  83+3  83+3  83+3  77+3
# 94   82+3  83+3  83+3  80+3  80+3  80+3  83+3
# 332  76+2  78+2  78+2  79+2  79+2  79+2  78+2
#
# [5 rows x 104 columns]

# %%
if fifa['height_cm']==175:
   print['short_name']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ;
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6152\4270509612.py in <module>
# ----> 1 if fifa['height_cm']==175:
#       2    print['short_name'].all();
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
fifa.iloc[3:7,4:-90]
# Out:
#    age         dob  height_cm  weight_kg nationality             club  \
# 3   26  1993-01-07        188         87    Slovenia  Atlético Madrid
# 4   28  1991-01-07        175         74     Belgium      Real Madrid
# 5   28  1991-06-28        181         70     Belgium  Manchester City
# 6   27  1992-04-30        187         85     Germany     FC Barcelona
#
#    overall  potential  value_eur  wage_eur
# 3       91         93   77500000    125000
# 4       91         91   90000000    470000
# 5       91         91   90000000    370000
# 6       90         93   67500000    250000
